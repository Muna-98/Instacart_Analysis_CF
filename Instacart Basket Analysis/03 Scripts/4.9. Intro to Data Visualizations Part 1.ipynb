# %% [markdown]
# ### Contents
#     01. Importing libraries and data
#     02. Data wrangling
#     03. Consistency and quality check
#     04. Combining the data
#     05. Exporting data

# %% [markdown]
# # 01. Importing libraries and data

# %%
#Importing pandas, numpy, os and data
import pandas as pd
import numpy as np
import os
path=r'C:\Users\Мунаввар\Desktop\bootcamps\Achievement 4\Instacart Basket Analysis'
df_customer=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col=False)
df=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'grouped_merged_data.pkl'))

# %% [markdown]
# # 02. Data wrangling

# %%
df_customer.shape
# Out:
# (206209, 10)

# %%
df_customer.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customer.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
#Renaming columns
df_customer.rename(columns={'user_id':'customer_id', 'First Name': 'first_name', 'Surnam':'last_name', 'STATE':'state', 'n_dependants':'number_of_dependants'}, inplace=True)

# %%
df_customer['date_joined'].value_counts()
# Out:
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: date_joined, Length: 1187, dtype: int64

# %%
df_customer.rename(columns={'Age':'age', 'Gender':'gender'}, inplace=True)

# %% [markdown]
# # 03. Consistency and quality check

# %%
df_customer.dtypes
# Out:
# customer_id              int64
# first_name              object
# last_name               object
# Gender                  object
# state                   object
# Age                      int64
# date_joined             object
# number_of_dependants     int64
# fam_status              object
# income                   int64
# dtype: object

# %%
#Check for mixed type data
for col in df_customer.columns.tolist():
  weird = (df_customer[[col]].applymap(type) != df_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customer[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
# Change types for  data set
df_customer['customer_id'] = df_customer['customer_id'].astype('int32')
df_customer['first_name']=df_customer['first_name'].astype('str')
df_customer['age']=df_customer['age'].astype('int8')
df_customer['number_of_dependants']=df_customer['number_of_dependants'].astype('int8')
df_customer['income']=df_customer['income'].astype('int32')

# %%
#Check for duplicates
df_dups=df_customer[df_customer.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [customer_id, first_name, last_name, gender, state, age, date_joined, number_of_dependants, fam_status, income]
# Index: []

# %%
#Check for missing data
df_customer.isnull().sum()
# Out:
# customer_id             0
# first_name              0
# last_name               0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# number_of_dependants    0
# fam_status              0
# income                  0
# dtype: int64

# %%
df_customer['first_name'].value_counts()
# Out:
# nan        11259
# Marilyn     2213
# Barbara     2154
# Todd        2113
# Jeremy      2104
#            ...
# Merry        197
# Eugene       197
# Garry        191
# Ned          186
# David        186
# Name: first_name, Length: 208, dtype: int64

# %%
df_customer=df_customer.replace('nan', np.NaN)

# %%
df_customer.isnull().sum()
# Out:
# customer_id                 0
# first_name              11259
# last_name                   0
# gender                      0
# state                       0
# age                         0
# date_joined                 0
# number_of_dependants        0
# fam_status                  0
# income                      0
# dtype: int64

# %%
df_missing=df_customer[df_customer['first_name'].isnull()==True]
df_missing
# Out:
#         customer_id first_name last_name  gender         state  age  \
# 53            76659        NaN   Gilbert    Male      Colorado   26
# 73            13738        NaN     Frost  Female     Louisiana   39
# 82            89996        NaN    Dawson  Female        Oregon   52
# 99            96166        NaN   Oconnor    Male      Oklahoma   51
# 105           29778        NaN    Dawson  Female          Utah   63
# ...             ...        ...       ...     ...           ...  ...
# 206038       121317        NaN    Melton    Male  Pennsylvania   28
# 206044       200799        NaN  Copeland  Female        Hawaii   52
# 206090       167394        NaN     Frost  Female        Hawaii   61
# 206162       187532        NaN     Floyd  Female    California   39
# 206171       116898        NaN   Delgado  Female      Colorado   23
#
#        date_joined  number_of_dependants fam_status  income
# 53        1/1/2017                     2    married   41709
# ...

# %% [markdown]
# ### Since missing first names have all the other information such as last name. user_id and etc., we will not delete them yet.

# %% [markdown]
# # 04. Combining the data

# %%
df.shape
# Out:
# (32404859, 23)

# %%
df_customer.shape
# Out:
# (206209, 10)

# %%
df.head()
# Out:
#    order_id  customer_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                  2                  8
# 1   2398795            1             2                  3                  7
# 2    473747            1             3                  3                 12
# 3   2254736            1             4                  4                  7
# 4    431534            1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge        price_range     busiest_day  \
# ...

# %%
#merging on customer_id
df_merged=df.merge(df_customer, on='customer_id')

# %%
df_merged.shape
# Out:
# (32404859, 32)

# %%
df_merged
# Out:
#           order_id  customer_id  order_number  order_day_of_week  \
# 0          2539329            1             1                  2
# 1          2398795            1             2                  3
# 2           473747            1             3                  3
# 3          2254736            1             4                  4
# 4           431534            1             5                  4
# ...            ...          ...           ...                ...
# 32404854    156685       106143            26                  4
# 32404855    484769        66343             1                  6
# 32404856   1561557        66343             2                  1
# 32404857    276317        66343             3                  6
# 32404858   2922475        66343             4                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %% [markdown]
# # 05. Exporting data

# %%
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_combined.pkl'))
